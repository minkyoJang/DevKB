# %%
pwd
# Out:
# 'C:\\Users\\Administrator'

# %%
filename = 'corpus.txt'

# %%
content = []
content2 = []
with open(filename,'r') as file:
    content.append(file.read())
    line_number = 1
    for line in content:
        content2.append(line.split('\n'))
        print(line_number,content2)
        line_number = line_number+1
        #content2.append(line.split('\n'))
    
    #print(content2)
    #print(content.split('\n'))
# Out:
# 1 [['zoo,768', 'zones,1168', 'zone,2553', 'zimbabwe,658', 'zero,2286', 'zealand,2636', 'zambia,732', 'yugoslavia,1400', 'youths,914', 'youth,5415', 'yourself,10746', 'yours,4241', 'your,138337', 'youngsters,1749', 'youngest,1204', 'younger,5403', 'young,33611', 'you,695595', 'yorkshire,4393', 'york,9906', 'yo,1206', 'yields,940', 'yield,2113', 'yet,33752', 'yesterday,19507', 'yes,60612', 'yer,1509', 'yep,1317', 'yeltsin,1192', 'yellow,4557', 'yelled,754', 'years,90224', 'year,73778', 'yeah,83382', 'ye,1700', 'yarn,877', 'yards,3678', 'yard,3267', 'yacht,1033', 'ya,1753', 'wycliffe,716', 'wrote,9909', 'wrong,16080', 'written,13675', 'writings,1063', 'writing,11582', 'writes,2607', 'writers,3581', 'writer,3742', 'write,10882', 'wrist,1056', 'wright,1972', 'wrapped,1723', 'wounds,1025', 'wounded,1692', 'wound,2161', 'would,255198', 'worthy,1403', 'worthwhile,1484', 'worth,12375', 'worst,4817', 'worship,1625', 'worse,7237', 'worrying,1473', 'worry,5585', 'worries,1308', 'worried,4594', 'worn,2099', 'worms,678', 'worldwide,2211', 'worlds,1068', 'world,59031', 'workstations,809', 'workstation,742', 'workshops,1405', 'workshop,1814', 'works,14528', 'workplace,846', 'workings,733', 'working-class,1900', 'working,29252', 'workforce,1530', 'workers,14724', 'worker,3635', 'worked,12748', 'work,91354', 'wore,3011', 'wordsworth,905', 'words,24444', 'wording,822', 'word,19379', 'worcester,737', 'wool,1783', 'woods,2135', 'woodland,1025', 'wooden,3547']]

# %%
con = []
with open(filename,'r') as file:
    con = file.read()
    print(con)
# Out:
# zoo,768
# zones,1168
# zone,2553
# zimbabwe,658
# zero,2286
# zealand,2636
# zambia,732
# yugoslavia,1400
# youths,914
# youth,5415
# yourself,10746
# yours,4241
# your,138337
# youngsters,1749
# youngest,1204
# younger,5403
# young,33611
# you,695595
# yorkshire,4393
# york,9906
# yo,1206
# yields,940
# yield,2113
# yet,33752
# yesterday,19507
# yes,60612
# yer,1509
# yep,1317
# yeltsin,1192
# yellow,4557
# yelled,754
# years,90224
# year,73778
# yeah,83382
# ye,1700
# yarn,877
# yards,3678
# yard,3267
# yacht,1033
# ya,1753
# wycliffe,716
# wrote,9909
# wrong,16080
# written,13675
# writings,1063
# writing,11582
# writes,2607
# writers,3581
# writer,3742
# write,10882
# wrist,1056
# wright,1972
# wrapped,1723
# wounds,1025
# wounded,1692
# wound,2161
# would,255198
# worthy,1403
# worthwhile,1484
# worth,12375
# worst,4817
# worship,1625
# worse,7237
# worrying,1473
# worry,5585
# worries,1308
# worried,4594
# worn,2099
# worms,678
# worldwide,2211
# worlds,1068
# world,59031
# workstations,809
# workstation,742
# workshops,1405
# workshop,1814
# works,14528
# workplace,846
# workings,733
# working-class,1900
# working,29252
# workforce,1530
# workers,14724
# worker,3635
# worked,12748
# work,91354
# wore,3011
# wordsworth,905
# words,24444
# wording,822
# word,19379
# worcester,737
# wool,1783
# woods,2135
# woodland,1025
# wooden,3547

# %%
con = []
with open(filename,'r') as file:
    con = file.read()
    line_number = 1
    for line in con:
        print(line)
# Out:
# z
# o
# o
# ,
# 7
# 6
# 8
#
#
# z
# o
# n
# e
# s
# ,
# 1
# 1
# 6
# 8
#
#
# z
# o
# n
# e
# ,
# 2
# 5
# 5
# 3
#
#
# z
# i
# m
# b
# a
# b
# w
# e
# ,
# 6
# 5
# 8
#
#
# z
# e
# r
# o
# ,
# 2
# 2
# 8
# 6
#
#
# z
# e
# a
# l
# a
# n
# d
# ,
# 2
# 6
# 3
# 6
#
#
# z
# a
# m
# b
# i
# a
# ,
# 7
# 3
# 2
#
#
# y
# u
# g
# o
# s
# l
# a
# v
# i
# a
# ,
# 1
# 4
# 0
# 0
#
#
# y
# o
# u
# t
# h
# s
# ,
# 9
# 1
# 4
#
#
# y
# o
# u
# t
# h
# ,
# 5
# 4
# 1
# 5
#
#
# y
# o
# u
# r
# s
# e
# l
# f
# ,
# 1
# 0
# 7
# 4
# 6
#
#
# y
# o
# u
# r
# s
# ,
# 4
# 2
# 4
# 1
#
#
# y
# o
# u
# r
# ,
# 1
# 3
# 8
# 3
# 3
# 7
#
#
# y
# o
# u
# n
# g
# s
# t
# e
# r
# s
# ,
# 1
# 7
# 4
# 9
#
#
# y
# o
# u
# n
# g
# e
# s
# t
# ,
# 1
# 2
# 0
# 4
#
#
# y
# o
# u
# n
# g
# e
# r
# ,
# 5
# 4
# 0
# 3
#
#
# y
# o
# u
# n
# g
# ,
# 3
# 3
# 6
# 1
# 1
#
#
# y
# o
# u
# ,
# 6
# 9
# 5
# 5
# 9
# 5
#
#
# y
# o
# r
# k
# s
# h
# i
# r
# e
# ,
# 4
# 3
# 9
# 3
#
#
# y
# o
# r
# k
# ,
# 9
# 9
# 0
# 6
#
#
# y
# o
# ,
# 1
# 2
# 0
# 6
#
#
# y
# i
# e
# l
# d
# s
# ,
# 9
# 4
# 0
#
#
# y
# i
# e
# l
# d
# ,
# 2
# 1
# 1
# 3
#
#
# y
# e
# t
# ,
# 3
# 3
# 7
# 5
# 2
#
#
# y
# e
# s
# t
# e
# r
# d
# a
# y
# ,
# 1
# 9
# 5
# 0
# 7
#
#
# y
# e
# s
# ,
# 6
# 0
# 6
# 1
# 2
#
#
# y
# e
# r
# ,
# 1
# 5
# 0
# 9
#
#
# y
# e
# p
# ,
# 1
# 3
# 1
# 7
#
#
# y
# e
# l
# t
# s
# i
# n
# ,
# 1
# 1
# 9
# 2
#
#
# y
# e
# l
# l
# o
# w
# ,
# 4
# 5
# 5
# 7
#
#
# y
# e
# l
# l
# e
# d
# ,
# 7
# 5
# 4
#
#
# y
# e
# a
# r
# s
# ,
# 9
# 0
# 2
# 2
# 4
#
#
# y
# e
# a
# r
# ,
# 7
# 3
# 7
# 7
# 8
#
#
# y
# e
# a
# h
# ,
# 8
# 3
# 3
# 8
# 2
#
#
# y
# e
# ,
# 1
# 7
# 0
# 0
#
#
# y
# a
# r
# n
# ,
# 8
# 7
# 7
#
#
# y
# a
# r
# d
# s
# ,
# 3
# 6
# 7
# 8
#
#
# y
# a
# r
# d
# ,
# 3
# 2
# 6
# 7
#
#
# y
# a
# c
# h
# t
# ,
# 1
# 0
# 3
# 3
#
#
# y
# a
# ,
# 1
# 7
# 5
# 3
#
#
# w
# y
# c
# l
# i
# f
# f
# e
# ,
# 7
# 1
# 6
#
#
# w
# r
# o
# t
# e
# ,
# 9
# 9
# 0
# 9
#
#
# w
# r
# o
# n
# g
# ,
# 1
# 6
# 0
# 8
# 0
#
#
# w
# r
# i
# t
# t
# e
# n
# ,
# 1
# 3
# 6
# 7
# 5
#
#
# w
# r
# i
# t
# i
# n
# g
# s
# ,
# 1
# 0
# 6
# 3
#
#
# w
# r
# i
# t
# i
# n
# g
# ,
# 1
# 1
# 5
# 8
# 2
#
#
# w
# r
# i
# t
# e
# s
# ,
# 2
# 6
# 0
# 7
#
#
# w
# r
# i
# t
# e
# r
# s
# ,
# 3
# 5
# 8
# 1
#
#
# w
# r
# i
# t
# e
# r
# ,
# 3
# 7
# 4
# 2
#
#
# w
# r
# i
# t
# e
# ,
# 1
# 0
# 8
# 8
# 2
#
#
# w
# r
# i
# s
# t
# ,
# 1
# 0
# 5
# 6
#
#
# w
# r
# i
# g
# h
# t
# ,
# 1
# 9
# 7
# 2
#
#
# w
# r
# a
# p
# p
# e
# d
# ,
# 1
# 7
# 2
# 3
#
#
# w
# o
# u
# n
# d
# s
# ,
# 1
# 0
# 2
# 5
#
#
# w
# o
# u
# n
# d
# e
# d
# ,
# 1
# 6
# 9
# 2
#
#
# w
# o
# u
# n
# d
# ,
# 2
# 1
# 6
# 1
#
#
# w
# o
# u
# l
# d
# ,
# 2
# 5
# 5
# 1
# 9
# 8
#
#
# w
# o
# r
# t
# h
# y
# ,
# 1
# 4
# 0
# 3
#
#
# w
# o
# r
# t
# h
# w
# h
# i
# l
# e
# ,
# 1
# 4
# 8
# 4
#
#
# w
# o
# r
# t
# h
# ,
# 1
# 2
# 3
# 7
# 5
#
#
# w
# o
# r
# s
# t
# ,
# 4
# 8
# 1
# 7
#
#
# w
# o
# r
# s
# h
# i
# p
# ,
# 1
# 6
# 2
# 5
#
#
# w
# o
# r
# s
# e
# ,
# 7
# 2
# 3
# 7
#
#
# w
# o
# r
# r
# y
# i
# n
# g
# ,
# 1
# 4
# 7
# 3
#
#
# w
# o
# r
# r
# y
# ,
# 5
# 5
# 8
# 5
#
#
# w
# o
# r
# r
# i
# e
# s
# ,
# 1
# 3
# 0
# 8
#
#
# w
# o
# r
# r
# i
# e
# d
# ,
# 4
# 5
# 9
# 4
#
#
# w
# o
# r
# n
# ,
# 2
# 0
# 9
# 9
#
#
# w
# o
# r
# m
# s
# ,
# 6
# 7
# 8
#
#
# w
# o
# r
# l
# d
# w
# i
# d
# e
# ,
# 2
# 2
# 1
# 1
#
#
# w
# o
# r
# l
# d
# s
# ,
# 1
# 0
# 6
# 8
#
#
# w
# o
# r
# l
# d
# ,
# 5
# 9
# 0
# 3
# 1
#
#
# w
# o
# r
# k
# s
# t
# a
# t
# i
# o
# n
# s
# ,
# 8
# 0
# 9
#
#
# w
# o
# r
# k
# s
# t
# a
# t
# i
# o
# n
# ,
# 7
# 4
# 2
#
#
# w
# o
# r
# k
# s
# h
# o
# p
# s
# ,
# 1
# 4
# 0
# 5
#
#
# w
# o
# r
# k
# s
# h
# o
# p
# ,
# 1
# 8
# 1
# 4
#
#
# w
# o
# r
# k
# s
# ,
# 1
# 4
# 5
# 2
# 8
#
#
# w
# o
# r
# k
# p
# l
# a
# c
# e
# ,
# 8
# 4
# 6
#
#
# w
# o
# r
# k
# i
# n
# g
# s
# ,
# 7
# 3
# 3
#
#
# w
# o
# r
# k
# i
# n
# g
# -
# c
# l
# a
# s
# s
# ,
# 1
# 9
# 0
# 0
#
#
# w
# o
# r
# k
# i
# n
# g
# ,
# 2
# 9
# 2
# 5
# 2
#
#
# w
# o
# r
# k
# f
# o
# r
# c
# e
# ,
# 1
# 5
# 3
# 0
#
#
# w
# o
# r
# k
# e
# r
# s
# ,
# 1
# 4
# 7
# 2
# 4
#
#
# w
# o
# r
# k
# e
# r
# ,
# 3
# 6
# 3
# 5
#
#
# w
# o
# r
# k
# e
# d
# ,
# 1
# 2
# 7
# 4
# 8
#
#
# w
# o
# r
# k
# ,
# 9
# 1
# 3
# 5
# 4
#
#
# w
# o
# r
# e
# ,
# 3
# 0
# 1
# 1
#
#
# w
# o
# r
# d
# s
# w
# o
# r
# t
# h
# ,
# 9
# 0
# 5
#
#
# w
# o
# r
# d
# s
# ,
# 2
# 4
# 4
# 4
# 4
#
#
# w
# o
# r
# d
# i
# n
# g
# ,
# 8
# 2
# 2
#
#
# w
# o
# r
# d
# ,
# 1
# 9
# 3
# 7
# 9
#
#
# w
# o
# r
# c
# e
# s
# t
# e
# r
# ,
# 7
# 3
# 7
#
#
# w
# o
# o
# l
# ,
# 1
# 7
# 8
# 3
#
#
# w
# o
# o
# d
# s
# ,
# 2
# 1
# 3
# 5
#
#
# w
# o
# o
# d
# l
# a
# n
# d
# ,
# 1
# 0
# 2
# 5
#
#
# w
# o
# o
# d
# e
# n
# ,
# 3
# 5
# 4
# 7

# %%
def print_lines(filename) :
    with open(filename) as file:
        line_number = 1
        for line in file:
            print(file.write(line_number,line))
            line_number +=1

# %%
print_lines(filename)

# %%
# 텍스트 파일을 불러옵니다.
filename = 'corpus.txt'
content = []

def import_as_tuple(filename):
    tuples = []
    with open(filename) as file:
        for line in file:
            print(line)

# %%
with open(filename) as file:
    for line in file:
        print(line)
# Out:
# zoo,768
#
# zones,1168
#
# zone,2553
#
# zimbabwe,658
#
# zero,2286
#
# zealand,2636
#
# zambia,732
#
# yugoslavia,1400
#
# youths,914
#
# youth,5415
#
# yourself,10746
#
# yours,4241
#
# your,138337
#
# youngsters,1749
#
# youngest,1204
#
# younger,5403
#
# young,33611
#
# you,695595
#
# yorkshire,4393
#
# york,9906
#
# yo,1206
#
# yields,940
#
# yield,2113
#
# yet,33752
#
# yesterday,19507
#
# yes,60612
#
# yer,1509
#
# yep,1317
#
# yeltsin,1192
#
# yellow,4557
#
# yelled,754
#
# years,90224
#
# year,73778
#
# yeah,83382
#
# ye,1700
#
# yarn,877
#
# yards,3678
#
# yard,3267
#
# yacht,1033
#
# ya,1753
#
# wycliffe,716
#
# wrote,9909
#
# wrong,16080
#
# written,13675
#
# writings,1063
#
# writing,11582
#
# writes,2607
#
# writers,3581
#
# writer,3742
#
# write,10882
#
# wrist,1056
#
# wright,1972
#
# wrapped,1723
#
# wounds,1025
#
# wounded,1692
#
# wound,2161
#
# would,255198
#
# worthy,1403
#
# worthwhile,1484
#
# worth,12375
#
# worst,4817
#
# worship,1625
#
# worse,7237
#
# worrying,1473
#
# worry,5585
#
# worries,1308
#
# worried,4594
#
# worn,2099
#
# worms,678
#
# worldwide,2211
#
# worlds,1068
#
# world,59031
#
# workstations,809
#
# workstation,742
#
# workshops,1405
#
# workshop,1814
#
# works,14528
#
# workplace,846
#
# workings,733
#
# working-class,1900
#
# working,29252
#
# workforce,1530
#
# workers,14724
#
# worker,3635
#
# worked,12748
#
# work,91354
#
# wore,3011
#
# wordsworth,905
#
# words,24444
#
# wording,822
#
# word,19379
#
# worcester,737
#
# wool,1783
#
# woods,2135
#
# woodland,1025
#
# wooden,3547

# %%
tuples = []
with open(filename) as file:
    for line in file:
        line2 = line.strip().split(',')
        word = line2[0]
        freq = line2[1]
        new_tuples = (word, freq)
        print(new_tuples)
# Out:
# ('zoo', '768')
# ('zones', '1168')
# ('zone', '2553')
# ('zimbabwe', '658')
# ('zero', '2286')
# ('zealand', '2636')
# ('zambia', '732')
# ('yugoslavia', '1400')
# ('youths', '914')
# ('youth', '5415')
# ('yourself', '10746')
# ('yours', '4241')
# ('your', '138337')
# ('youngsters', '1749')
# ('youngest', '1204')
# ('younger', '5403')
# ('young', '33611')
# ('you', '695595')
# ('yorkshire', '4393')
# ('york', '9906')
# ('yo', '1206')
# ('yields', '940')
# ('yield', '2113')
# ('yet', '33752')
# ('yesterday', '19507')
# ('yes', '60612')
# ('yer', '1509')
# ('yep', '1317')
# ('yeltsin', '1192')
# ('yellow', '4557')
# ('yelled', '754')
# ('years', '90224')
# ('year', '73778')
# ('yeah', '83382')
# ('ye', '1700')
# ('yarn', '877')
# ('yards', '3678')
# ('yard', '3267')
# ('yacht', '1033')
# ('ya', '1753')
# ('wycliffe', '716')
# ('wrote', '9909')
# ('wrong', '16080')
# ('written', '13675')
# ('writings', '1063')
# ('writing', '11582')
# ('writes', '2607')
# ('writers', '3581')
# ('writer', '3742')
# ('write', '10882')
# ('wrist', '1056')
# ('wright', '1972')
# ('wrapped', '1723')
# ('wounds', '1025')
# ('wounded', '1692')
# ('wound', '2161')
# ('would', '255198')
# ('worthy', '1403')
# ('worthwhile', '1484')
# ('worth', '12375')
# ('worst', '4817')
# ('worship', '1625')
# ('worse', '7237')
# ('worrying', '1473')
# ('worry', '5585')
# ('worries', '1308')
# ('worried', '4594')
# ('worn', '2099')
# ('worms', '678')
# ('worldwide', '2211')
# ('worlds', '1068')
# ('world', '59031')
# ('workstations', '809')
# ('workstation', '742')
# ('workshops', '1405')
# ('workshop', '1814')
# ('works', '14528')
# ('workplace', '846')
# ('workings', '733')
# ('working-class', '1900')
# ('working', '29252')
# ('workforce', '1530')
# ('workers', '14724')
# ('worker', '3635')
# ('worked', '12748')
# ('work', '91354')
# ('wore', '3011')
# ('wordsworth', '905')
# ('words', '24444')
# ('wording', '822')
# ('word', '19379')
# ('worcester', '737')
# ('wool', '1783')
# ('woods', '2135')
# ('woodland', '1025')
# ('wooden', '3547')

# %%
tuples = []
with open(filename) as file:
    for line in file:
        line2 = line.strip().split(',')
        word = line2[0]
        freq = line2[1]
        new_tuples = (word, freq)
        tuples.append(new_tuples)
        print(tuples)
# Out:
# [('zoo', '768')]
# [('zoo', '768'), ('zones', '1168')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678')]
# ...
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379'), ('worcester', '737')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379'), ('worcester', '737'), ('wool', '1783')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379'), ('worcester', '737'), ('wool', '1783'), ('woods', '2135')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379'), ('worcester', '737'), ('wool', '1783'), ('woods', '2135'), ('woodland', '1025')]
# [('zoo', '768'), ('zones', '1168'), ('zone', '2553'), ('zimbabwe', '658'), ('zero', '2286'), ('zealand', '2636'), ('zambia', '732'), ('yugoslavia', '1400'), ('youths', '914'), ('youth', '5415'), ('yourself', '10746'), ('yours', '4241'), ('your', '138337'), ('youngsters', '1749'), ('youngest', '1204'), ('younger', '5403'), ('young', '33611'), ('you', '695595'), ('yorkshire', '4393'), ('york', '9906'), ('yo', '1206'), ('yields', '940'), ('yield', '2113'), ('yet', '33752'), ('yesterday', '19507'), ('yes', '60612'), ('yer', '1509'), ('yep', '1317'), ('yeltsin', '1192'), ('yellow', '4557'), ('yelled', '754'), ('years', '90224'), ('year', '73778'), ('yeah', '83382'), ('ye', '1700'), ('yarn', '877'), ('yards', '3678'), ('yard', '3267'), ('yacht', '1033'), ('ya', '1753'), ('wycliffe', '716'), ('wrote', '9909'), ('wrong', '16080'), ('written', '13675'), ('writings', '1063'), ('writing', '11582'), ('writes', '2607'), ('writers', '3581'), ('writer', '3742'), ('write', '10882'), ('wrist', '1056'), ('wright', '1972'), ('wrapped', '1723'), ('wounds', '1025'), ('wounded', '1692'), ('wound', '2161'), ('would', '255198'), ('worthy', '1403'), ('worthwhile', '1484'), ('worth', '12375'), ('worst', '4817'), ('worship', '1625'), ('worse', '7237'), ('worrying', '1473'), ('worry', '5585'), ('worries', '1308'), ('worried', '4594'), ('worn', '2099'), ('worms', '678'), ('worldwide', '2211'), ('worlds', '1068'), ('world', '59031'), ('workstations', '809'), ('workstation', '742'), ('workshops', '1405'), ('workshop', '1814'), ('works', '14528'), ('workplace', '846'), ('workings', '733'), ('working-class', '1900'), ('working', '29252'), ('workforce', '1530'), ('workers', '14724'), ('worker', '3635'), ('worked', '12748'), ('work', '91354'), ('wore', '3011'), ('wordsworth', '905'), ('words', '24444'), ('wording', '822'), ('word', '19379'), ('worcester', '737'), ('wool', '1783'), ('woods', '2135'), ('woodland', '1025'), ('wooden', '3547')]

# %% [markdown]
# ### -------------------------

# %%
pairs = [
    ('time', 8),
    ('the', 15),
    ('turbo', 1),
]



#(단어, 빈도수) 쌍으로 이루어진 튜플을 받아, 빈도수를 리턴합니다.    
def get_freq(pair):
    return pair[1]

# %%
get_freq(pairs)
# Out:
# ('the', 15)

# %%
#(단어, 빈도수) 꼴 튜플의 리스트를 받아, 빈도수가 낮은 순서대로 정렬하여 리턴합니다.
def sort_by_frequency(pairs):
    return sorted(pairs, key = get_freq)


# 아래 주석을 해제하고 결과를 확인해보세요.  
print(sort_by_frequency(pairs))
# Out:
# [('turbo', 1), ('time', 8), ('the', 15)]

# %%
#(단어, 빈도수) 꼴 튜플의 리스트를 받아, 빈도수가 낮은 순서대로 정렬하여 리턴합니다.
def sort_by_frequency(pairs):
    return sorted(pairs, reversed(key =get_freq))


# 아래 주석을 해제하고 결과를 확인해보세요.  
print(sort_by_frequency(pairs))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-85af359aa3d3> in <module>
#       5
#       6 # 아래 주석을 해제하고 결과를 확인해보세요.
# ----> 7 print(sort_by_frequency(pairs))
#
# <ipython-input-5-85af359aa3d3> in sort_by_frequency(pairs)
#       1 #(단어, 빈도수) 꼴 튜플의 리스트를 받아, 빈도수가 낮은 순서대로 정렬하여 리턴합니다.
#       2 def sort_by_frequency(pairs):
# ----> 3     return sorted(pairs, reversed(key =get_freq))
#       4
#       5
#
# TypeError: reversed() takes no keyword arguments

# %%
### ---------------

# %%
years = [2013, 2014, 2015, 2016, 2017]
temperatures = [5, 10, 15, 20, 17]

#막대 차트를 출력합니다.   
    # 막대 그래프의 막대 위치를 결정하는 pos를 선언합니다.
pos = range(len(years))  # [0, 1, 2, 3, 4]

# %%
print(pos)
# Out:
# range(0, 5)

# %%
print(len(years))
# Out:
# 5

# %%
# matplotlib의 일부인 pyplot 라이브러리를 불러옵니다.
import matplotlib.pyplot as plt

# 엘리스에서 차트를 그릴 때 필요한 라이브러리를 불러옵니다.
from elice_utils import EliceUtils
elice_utils = EliceUtils()

# 월별 평균 기온을 선언합니다. 수정하지 마세요.
years = [2013, 2014, 2015, 2016, 2017]
temperatures = [5, 10, 15, 20, 17]

#막대 차트를 출력합니다.   
def draw_graph():
    # 막대 그래프의 막대 위치를 결정하는 pos를 선언합니다.
    pos = range(len(years))  # [0, 1, 2, 3, 4]
    
    # 높이가 온도인 막대 그래프를 그립니다.
    # 각 막대를 가운데 정렬합니다.
    plt.bar(pos, temperatures, align='center')
    
    # 각 막대에 해당되는 연도를 표기합니다.
    plt.xticks(pos, years)
    
    # 그래프를 엘리스 플랫폼 상에 표시합니다.
    plt.savefig('graph.png')
    elice_utils.send_image('graph.png')

print('막대 차트를 출력합니다.')
draw_graph()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-46346f737ec6> in <module>
#       3
#       4 # 엘리스에서 차트를 그릴 때 필요한 라이브러리를 불러옵니다.
# ----> 5 from elice_utils import EliceUtils
#       6 elice_utils = EliceUtils()
#       7
#
# ModuleNotFoundError: No module named 'elice_utils'

# %%
con = "i am good at eating this things"

# %%
con.split()
# Out:
# ['i', 'am', 'good', 'at', 'eating', 'this', 'things']

# %%
str = "I am a good boy"

# %%
str2 = str.replace("a","b")

# %%
print(str2)
# Out:
# I bm b good boy

# %%
tup = (1,2,3,4)

# %%
for i in tup:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
nums = [1, 2, 3, 4]

# %%
new_nums = [n for n in nums if n % 2 == 1]

# %%
new_nums
# Out:
# [1, 3]

# %%
Li = ["apple", "cherry", "banana"]

# %%
sorted(Li)
# Out:
# ['apple', 'banana', 'cherry']

# %%
pos = [0, 1, 2, 3]

# %%
years = [2020, 2021, 2022, 2023]

# %%
plt.bar(years, temperatures, align='center')
plt.xticks(years, pos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7bfecb366de2> in <module>
# ----> 1 plt.bar(years, temperatures, align='center')
#       2 plt.xticks(years, pos)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# ### -------------

# %%
content = '''

1:1012
2:3781
3:1732
4:889
5:2345
6:107
7:379

'''

# %%
with open("netflix.txt","w") as f:
    f.write(content)

# %% [markdown]
# 데이터 분석에 이용하기
# 사용자 번호: 작품 번호로 이루어진 netflix.txt을 읽고, 사용자 번호를 키로, 작품 번호를 값으로 하는 딕셔너리를 생성하는 make_dictionary() 함수를 완성하세요

# %%
# 텍스트 파일을 불러옵니다.
source_file = "netflix.txt"

# %%
with open (source_file) as file:
    for line in file:
        print(line)
# Out:
# 1:1012
#
# 2:3781
#
# 3:1732
#
# 4:889
#
# 5:2345
#
# 6:107
#
# 7:379

# %%
with open (source_file) as file:
    for line in file:
        key, values = line.split(":")

# %%
us = {}
a = "1:1012"
b = "2:3781"
key, values = a.split(":")
key2, values2 = b.split(":")
# print("key:",key)
# print("values:",values)

us[key] =  values
us[key2] = values2
us
# Out:
# {'1': '1012', '2': '3781'}

# %%
def make_dictionary(filename):
    user_to_titles = {}
    with open(filename) as file:
        for line in file:
            # 아래 코드를 작성하세요.
            user, title = line.split(":")
            user_to_titles[user] = title
            
            
            
        return user_to_titles


# 아래 주석을 해제하고 결과를 확인해보세요.  
print(make_dictionary(source_file))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-6086e35f6737> in <module>
#      13
#      14 # 아래 주석을 해제하고 결과를 확인해보세요.
# ---> 15 print(make_dictionary(source_file))
#
# <ipython-input-69-6086e35f6737> in make_dictionary(filename)
#       4         for line in file:
#       5             # 아래 코드를 작성하세요.
# ----> 6             user, title = line.split(":")
#       7             user_to_titles[user] = title
#       8
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# 사용자가 시청한 작품의 리스트를 저장합니다. 수정하지 마세요. 
user_to_titles = {
    1: [271, 318, 491],
    2: [318, 19, 2980, 475],
    3: [475],
    4: [271, 318, 491, 2980, 19, 318, 475],
    5: [882, 91, 2980, 557, 35],
}

# %%
new = {}
for key, value in user_to_titles.items():
    new[len(key)] = value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-9542b59ac051> in <module>
#       1 new = {}
#       2 for key, value in user_to_titles.items():
# ----> 3     new[len(key)] = value
#
# TypeError: object of type 'int' has no len()

# %%
print(new)
# Out:
# {1: [271, 318, 491], 2: [318, 19, 2980, 475], 3: [475], 4: [271, 318, 491, 2980, 19, 318, 475], 5: [882, 91, 2980, 557, 35]}

# %%
'''
num을 제곱한 값을 리턴합니다.
'''
def _square(num):
    return num * num

# _square()와 동일한 기능을 하는 lambda 함수 square를 만들어 보세요.
square = lambda n : n*n

'''
string이 빈 문자열일 경우 빈 문자열을, 아니면 첫 번째 글자를 리턴합니다.
'''
def _first_letter(string):
#    return string[0] if string !='' else ''
    return string[0] if string else ''

#first_letter = lambda string : '' if string != '' else string[0] 
first_letter = lambda string : string[0] if string else ''

# assert를 이용하여 두 함수의 기능이 동일한 지 테스트합니다. 아래 주석을 해제하고 결과 값을 확인해보세요.
testcases1 = [3, 10, 7, 1, -5]
for num in testcases1:
    assert(_square(num) == square(num))

testcases2 = ['', 'hello', 'elice', 'abracadabra', '  abcd  ']
for string in testcases2:
    assert(_first_letter(string) == first_letter(string))

# 위의 assert 테스트를 모두 통과해야만 아래의 print문이 실행됩니다.
print("성공했습니다!")
# Out:
# 성공했습니다!

# %%
##################

# %% [markdown]
# 함수를 리턴하는 함수
# 파이썬의 함수는 함수를 리턴값으로 가질 수 있습니다. 지금까지는 정수, 문자열과 같은 변수만을 리턴했지만, 종종 함수를 리턴값으로 갖는 경우도 있습니다.
#
# itemgetter() 함수가 대표적인 예입니다. itemgetter의 리턴값은 데이터의 모음을 받아 n번째 원소를 리턴하는 함수입니다.

# %% [markdown]
# 데이터 분석에서 이용하기
# 데이터가 특정 범위에 속하는 유효한 값인지 검증하는 함수를 Validator 함수라고 부릅니다.
#
# 이 실습에서는 데이터가 특정 범위의 정수값이 맞는지 확인하는 min_validator()와 max_validator() 함수를 완성해 봅니다.

# %%
from operator import itemgetter

# %%
get_zeroth = itemgetter(0)

# %%
numbers = [1,2,3]

# %%
print(get_zeroth(numbers))
# Out:
# 1

# %%
from operator import itemgetter
get_firsth = itemgetter(1)
print(get_firsth(numbers))
# Out:
# 2

# %%
def adder (n) :
    def helper (x):
        return x+n
    return helper

# %%
add_three = adder(3)

# %%
print(add_three(6))
# Out:
# 9

# %%
add_three(10)
# Out:
# 13

# %%
'''
주어진 값이 정수가 아니거나 최솟값 minimum보다 작으면 False를 리턴하는 함수를 리턴합니다.

'''
def min_validator(minimum):
    def helper(n):
        # n의 타입이 정수가 아니면 False를 리턴합니다.
        if type(n) is not int:
            return False
            
        if minimum <= n:
            return True
        else:
            return False
    return helper
    
    
'''    
주어진 값이 정수가 아니거나 최댓값 maximum보다 크면 False를 리턴하는 함수를 리턴합니다.
'''
def max_validator(maximum):
    def helper(n):
        # n의 타입이 정수가 아니면 False를 리턴합니다.
        if type(n) is not int:
            return False
        if n > maximum:
            return False
        else:
            return True
        
    return helper


def validate(n, validators):
    # validator 중 하나라도 통과하지 못하면 False를 리턴합니다.
    for validator in validators:
        if not validator(n):
            return False
    
    return True


# 작성한 함수를 테스트합니다. # 아래 주석을 해제하고 결과 값을 확인해보세요.
# # 나이 데이터를 검증하는 validator를 선언합니다. 
age_validators = [min_validator(0), max_validator(120)]
ages = [9, -3, 7, 33, 18, 1999, 287, 0, 13]

# 주어진 나이 데이터들에 대한 검증 결과를 출력합니다.
print("검증 결과")
for age in ages:
    result = "유효함" if validate(age, age_validators) else "유효하지 않음"
    print("{}세 : {}".format(age, result))
# Out:
# 검증 결과
# 9세 : 유효함
# -3세 : 유효하지 않음
# 7세 : 유효함
# 33세 : 유효함
# 18세 : 유효함
# 1999세 : 유효하지 않음
# 287세 : 유효하지 않음
# 0세 : 유효함
# 13세 : 유효함

# %%
def validate(n, validators):
    # validator 중 하나라도 통과하지 못하면 False를 리턴합니다.
    for validator in validators:
        if not validator(n):
            return False
    
    return True

# %%
age_validators = [min_validator(0), max_validator(120)]
ages = [9, -3, 7, 33, 18, 1999, 287, 0, 13]

# %%
validate(age, age_validators)
# Out:
# True

# %%
[func(x) for x in data]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d6731789ea8d> in <module>
# ----> 1 [func(x) for x in data]
#
# NameError: name 'data' is not defined

# %% [markdown]
# 리스트에 함수 적용하기
# map()은 데이터 구조의 각 원소들에 동일한 함수를 적용하여 새로운 데이터를 만드는 파이썬의 기본 함수입니다. data라는 리스트가 주어졌을 때, 아래의 두 코드는 유사한 연산을 합니다.

# %%
map(func, data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-2c48b664b4cf> in <module>
# ----> 1 map(func, data)
#
# NameError: name 'func' is not defined

# %% [markdown]
# List comprehension과 map()의 가장 주된 차이점은 연산을 진행하는 시점입니다. map()의 경우 데이터를 map이라는 클래스로 저장하고, 데이터가 필요해질 때 주어진 연산을 수행합니다.
#
#
# 실습하기
# 앞서 보았던 books.csv 파일을 읽어서 제목의 리스트를 리턴하는 get_titles() 함수를 완성하세요.

# %%
pwd
# Out:
# 'C:\\Users\\Administrator'

# %%
    with open(books_csv) as books:
        reader = csv.reader(books, delimiter=',')
        # 함수를 완성하세요.
        get_title = lambda row: row[0]
        titles = None
        return list(titles)
# Out:
#   File "<ipython-input-29-f5eaa952b1fc>", line 6
#     return list(titles)
#     ^
# SyntaxError: 'return' outside function

# %%
import csv 

with open('books.csv') as books:
    reader = csv.reader(books, delimiter = ',')
    get_title = lambda row : row[0]
    titles = map(get_title, reader)
    return list(titles)
# Out:
#   File "<ipython-input-38-f46c97e6ae88>", line 7
#     return list(titles)
#     ^
# SyntaxError: 'return' outside function
